# %%
"""
Main script for training and evaluating ML models on the Ireland water quality dataset.
Similiar to the final main.py but with less detailed analysis
"""

import os
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
# ── Config ─────────────────────────────────────────────────────────────────
DATA_PATH  = "data/Dataset/Country-Wise Data/Ireland_dataset.csv"
OUTPUT_DIR = "output"
FEATURES = [
    "Ammonia (mg/l)",
    "Biochemical Oxygen Demand (mg/l)",
    "Dissolved Oxygen (mg/l)",
    "Orthophosphate (mg/l)",
    "pH (ph units)",
    "Temperature (cel)",
    "Nitrogen (mg/l)",
    "Nitrate (mg/l)",
]
TARGET      = "CCME_Values"   # numeric WQI score (0–100); CCME_WQI is the category label
RANDOM_SEED = 42
TEST_SIZE   = 0.1
VAL_SIZE    = 0.1

os.makedirs(OUTPUT_DIR, exist_ok=True)

# %%
# ── 1. Load data ─────────────────────────────────────────────────────────────
df = pd.read_csv(DATA_PATH)
print(f"Dataset shape: {df.shape}")

X = df[FEATURES].values
y = df[TARGET].values.astype(float)   # continuous WQI score (0–100)

print(f"\nTarget statistics:")
print(f"  Mean:  {y.mean():.2f}")
print(f"  Std:   {y.std():.2f}")
print(f"  Min:   {y.min():.2f}")
print(f"  Max:   {y.max():.2f}")
# Out:
# Dataset shape: (235019, 14)
#
# Target statistics:
#   Mean:  98.11
#   Std:   6.41
#   Min:   37.19
#   Max:   100.00

# %%
# ── 2. IQR outlier removal (1.5× inner fence, matching baseline) ─────────────
df_clean = df[FEATURES + [TARGET]].copy()
for col in FEATURES:
    Q1, Q3 = df_clean[col].quantile(0.25), df_clean[col].quantile(0.75)
    IQR = Q3 - Q1
    df_clean = df_clean[(df_clean[col] >= Q1 - 1.5 * IQR) & (df_clean[col] <= Q3 + 1.5 * IQR)]

X = df_clean[FEATURES].values
y = df_clean[TARGET].values.astype(float)
print(f"After outlier removal: {len(df_clean):,} rows  (removed {len(df) - len(df_clean):,})")
# Out:
# After outlier removal: 50,125 rows  (removed 184,894)

# %%
# ── 3. Train / val / test split ──────────────────────────────────────────────
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=TEST_SIZE, random_state=RANDOM_SEED
)
X_train, X_val, y_train, y_val = train_test_split(
    X_train, y_train, test_size=VAL_SIZE, random_state=RANDOM_SEED
)
print(f"Train: {X_train.shape[0]:,}  Val: {X_val.shape[0]:,}  Test: {X_test.shape[0]:,}")
# Out:
# Train: 40,600  Val: 4,512  Test: 5,013

# %%
# ── 4. Feature scaling ──────────────────────────────────────────────────────
# (merged into cell 5 — this cell intentionally left as a pass-through)
pass

# %%
# ── 5. Scale features + target ───────────────────────────────────────────────
from sklearn.preprocessing import MinMaxScaler

scaler   = StandardScaler()
X_train  = scaler.fit_transform(X_train)
X_val    = scaler.transform(X_val)
X_test   = scaler.transform(X_test)

y_scaler  = MinMaxScaler()
y_train_s = y_scaler.fit_transform(y_train.reshape(-1, 1)).flatten()
y_val_s   = y_scaler.transform(y_val.reshape(-1, 1)).flatten()
# y_test stays unscaled — we inverse-transform predictions for evaluation
print("Features: StandardScaler | Target: MinMaxScaler (fit on train only)")
# Out:
# Features: StandardScaler | Target: MinMaxScaler (fit on train only)

# %%
# ── 6. Build regression model ────────────────────────────────────────────────
tf.random.set_seed(RANDOM_SEED)

model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(len(FEATURES),)),

    tf.keras.layers.Dense(128, activation="relu"),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.3),

    tf.keras.layers.Dense(64, activation="relu"),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.3),

    tf.keras.layers.Dense(32, activation="relu"),
    tf.keras.layers.Dropout(0.2),

    tf.keras.layers.Dense(1),   # linear output — continuous WQI score
])

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss="mse",
    metrics=["mae"],
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 128)            │         1,152 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 12,289 (48.00 KB)
#  Trainable params: 11,905 (46.50 KB)
#  Non-trainable params: 384 (1.50 KB)

# %%
# ── 7. Callbacks ────────────────────────────────────────────────────────────
callbacks = [
    tf.keras.callbacks.EarlyStopping(
        monitor="val_loss", patience=10, restore_best_weights=True
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=5, min_lr=1e-6, verbose=1
    ),
]

# %%
# ── 8. Train ─────────────────────────────────────────────────────────────────
history = model.fit(
    X_train, y_train_s,
    validation_data=(X_val, y_val_s),
    epochs=100,
    batch_size=256,
    callbacks=callbacks,
    verbose=1,
)
# Out:
# Epoch 1/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.7223 - mae: 0.6260 - val_loss: 0.0957 - val_mae: 0.2645 - learning_rate: 0.0010
# Epoch 2/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2198 - mae: 0.3609 - val_loss: 0.0421 - val_mae: 0.1518 - learning_rate: 0.0010
# Epoch 3/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1240 - mae: 0.2712 - val_loss: 0.0321 - val_mae: 0.1304 - learning_rate: 0.0010
# Epoch 4/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0834 - mae: 0.2217 - val_loss: 0.0259 - val_mae: 0.1140 - learning_rate: 0.0010
# Epoch 5/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0613 - mae: 0.1885 - val_loss: 0.0241 - val_mae: 0.1140 - learning_rate: 0.0010
# Epoch 6/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0468 - mae: 0.1633 - val_loss: 0.0223 - val_mae: 0.1108 - learning_rate: 0.0010
# Epoch 7/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0380 - mae: 0.1457 - val_loss: 0.0208 - val_mae: 0.1111 - learning_rate: 0.0010
# Epoch 8/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0317 - mae: 0.1312 - val_loss: 0.0161 - val_mae: 0.0945 - learning_rate: 0.0010
# Epoch 9/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0266 - mae: 0.1179 - val_loss: 0.0155 - val_mae: 0.0952 - learning_rate: 0.0010
# Epoch 10/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0230 - mae: 0.1076 - val_loss: 0.0130 - val_mae: 0.0844 - learning_rate: 0.0010
# Epoch 11/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0200 - mae: 0.0984 - val_loss: 0.0116 - val_mae: 0.0760 - learning_rate: 0.0010
# Epoch 12/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0173 - mae: 0.0897 - val_loss: 0.0107 - val_mae: 0.0716 - learning_rate: 0.0010
# Epoch 13/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0154 - mae: 0.0822 - val_loss: 0.0095 - val_mae: 0.0628 - learning_rate: 0.0010
# Epoch 14/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0138 - mae: 0.0750 - val_loss: 0.0085 - val_mae: 0.0555 - learning_rate: 0.0010
# Epoch 15/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0124 - mae: 0.0693 - val_loss: 0.0081 - val_mae: 0.0527 - learning_rate: 0.0010
# Epoch 16/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0112 - mae: 0.0631 - val_loss: 0.0076 - val_mae: 0.0497 - learning_rate: 0.0010
# Epoch 17/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0102 - mae: 0.0576 - val_loss: 0.0071 - val_mae: 0.0453 - learning_rate: 0.0010
# Epoch 18/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0093 - mae: 0.0528 - val_loss: 0.0064 - val_mae: 0.0398 - learning_rate: 0.0010
# Epoch 19/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0086 - mae: 0.0484 - val_loss: 0.0061 - val_mae: 0.0359 - learning_rate: 0.0010
# Epoch 20/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0078 - mae: 0.0439 - val_loss: 0.0055 - val_mae: 0.0320 - learning_rate: 0.0010
# Epoch 21/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0071 - mae: 0.0402 - val_loss: 0.0052 - val_mae: 0.0270 - learning_rate: 0.0010
# Epoch 22/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0068 - mae: 0.0363 - val_loss: 0.0048 - val_mae: 0.0233 - learning_rate: 0.0010
# Epoch 23/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0062 - mae: 0.0326 - val_loss: 0.0043 - val_mae: 0.0201 - learning_rate: 0.0010
# Epoch 24/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0057 - mae: 0.0289 - val_loss: 0.0039 - val_mae: 0.0175 - learning_rate: 0.0010
# Epoch 25/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0052 - mae: 0.0256 - val_loss: 0.0038 - val_mae: 0.0156 - learning_rate: 0.0010
# Epoch 26/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0051 - mae: 0.0229 - val_loss: 0.0038 - val_mae: 0.0164 - learning_rate: 0.0010
# Epoch 27/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0047 - mae: 0.0207 - val_loss: 0.0034 - val_mae: 0.0130 - learning_rate: 0.0010
# Epoch 28/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0046 - mae: 0.0188 - val_loss: 0.0032 - val_mae: 0.0126 - learning_rate: 0.0010
# Epoch 29/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0044 - mae: 0.0174 - val_loss: 0.0031 - val_mae: 0.0108 - learning_rate: 0.0010
# Epoch 30/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0041 - mae: 0.0162 - val_loss: 0.0030 - val_mae: 0.0086 - learning_rate: 0.0010
# Epoch 31/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0041 - mae: 0.0151 - val_loss: 0.0029 - val_mae: 0.0087 - learning_rate: 0.0010
# Epoch 32/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0039 - mae: 0.0147 - val_loss: 0.0030 - val_mae: 0.0091 - learning_rate: 0.0010
# Epoch 33/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0039 - mae: 0.0144 - val_loss: 0.0028 - val_mae: 0.0081 - learning_rate: 0.0010
# Epoch 34/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0036 - mae: 0.0139 - val_loss: 0.0029 - val_mae: 0.0081 - learning_rate: 0.0010
# Epoch 35/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0036 - mae: 0.0132 - val_loss: 0.0026 - val_mae: 0.0079 - learning_rate: 0.0010
# Epoch 36/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0035 - mae: 0.0133 - val_loss: 0.0027 - val_mae: 0.0077 - learning_rate: 0.0010
# Epoch 37/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0035 - mae: 0.0130 - val_loss: 0.0025 - val_mae: 0.0086 - learning_rate: 0.0010
# Epoch 38/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0035 - mae: 0.0128 - val_loss: 0.0024 - val_mae: 0.0082 - learning_rate: 0.0010
# Epoch 39/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0031 - mae: 0.0122 - val_loss: 0.0025 - val_mae: 0.0090 - learning_rate: 0.0010
# Epoch 40/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0032 - mae: 0.0122 - val_loss: 0.0023 - val_mae: 0.0113 - learning_rate: 0.0010
# Epoch 41/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0027 - mae: 0.0112 - val_loss: 0.0023 - val_mae: 0.0078 - learning_rate: 0.0010
# Epoch 42/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0029 - mae: 0.0113 - val_loss: 0.0022 - val_mae: 0.0110 - learning_rate: 0.0010
# Epoch 43/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0027 - mae: 0.0107 - val_loss: 0.0023 - val_mae: 0.0062 - learning_rate: 0.0010
# Epoch 44/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0028 - mae: 0.0115 - val_loss: 0.0021 - val_mae: 0.0090 - learning_rate: 0.0010
# Epoch 45/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0025 - mae: 0.0110 - val_loss: 0.0020 - val_mae: 0.0079 - learning_rate: 0.0010
# Epoch 46/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0025 - mae: 0.0106 - val_loss: 0.0023 - val_mae: 0.0070 - learning_rate: 0.0010
# Epoch 47/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0025 - mae: 0.0106 - val_loss: 0.0019 - val_mae: 0.0063 - learning_rate: 0.0010
# Epoch 48/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0023 - mae: 0.0104 - val_loss: 0.0017 - val_mae: 0.0053 - learning_rate: 0.0010
# Epoch 49/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0023 - mae: 0.0094 - val_loss: 0.0018 - val_mae: 0.0048 - learning_rate: 0.0010
# Epoch 50/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0022 - mae: 0.0099 - val_loss: 0.0018 - val_mae: 0.0055 - learning_rate: 0.0010
# Epoch 51/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0019 - mae: 0.0089 - val_loss: 0.0014 - val_mae: 0.0051 - learning_rate: 0.0010
# Epoch 52/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0019 - mae: 0.0088 - val_loss: 0.0013 - val_mae: 0.0048 - learning_rate: 0.0010
# Epoch 53/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0018 - mae: 0.0086 - val_loss: 0.0014 - val_mae: 0.0046 - learning_rate: 0.0010
# Epoch 54/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0016 - mae: 0.0082 - val_loss: 0.0011 - val_mae: 0.0045 - learning_rate: 0.0010
# Epoch 55/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0018 - mae: 0.0081 - val_loss: 0.0013 - val_mae: 0.0048 - learning_rate: 0.0010
# Epoch 56/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0015 - mae: 0.0074 - val_loss: 9.7721e-04 - val_mae: 0.0039 - learning_rate: 0.0010
# Epoch 57/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0015 - mae: 0.0075 - val_loss: 0.0012 - val_mae: 0.0058 - learning_rate: 0.0010
# Epoch 58/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0015 - mae: 0.0075 - val_loss: 9.3757e-04 - val_mae: 0.0041 - learning_rate: 0.0010
# Epoch 59/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0014 - mae: 0.0072 - val_loss: 9.8931e-04 - val_mae: 0.0039 - learning_rate: 0.0010
# Epoch 60/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0013 - mae: 0.0070 - val_loss: 8.1339e-04 - val_mae: 0.0035 - learning_rate: 0.0010
# Epoch 61/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0014 - mae: 0.0069 - val_loss: 9.9803e-04 - val_mae: 0.0044 - learning_rate: 0.0010
# Epoch 62/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0012 - mae: 0.0065 - val_loss: 8.8540e-04 - val_mae: 0.0033 - learning_rate: 0.0010
# Epoch 63/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0014 - mae: 0.0068 - val_loss: 0.0012 - val_mae: 0.0050 - learning_rate: 0.0010
# Epoch 64/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0012 - mae: 0.0063 - val_loss: 8.0494e-04 - val_mae: 0.0040 - learning_rate: 0.0010
# Epoch 65/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0012 - mae: 0.0065 - val_loss: 6.9944e-04 - val_mae: 0.0047 - learning_rate: 0.0010
# Epoch 66/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0011 - mae: 0.0060 - val_loss: 6.5592e-04 - val_mae: 0.0034 - learning_rate: 0.0010
# Epoch 67/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0011 - mae: 0.0057 - val_loss: 6.1979e-04 - val_mae: 0.0034 - learning_rate: 0.0010
# Epoch 68/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0011 - mae: 0.0059 - val_loss: 0.0013 - val_mae: 0.0037 - learning_rate: 0.0010
# Epoch 69/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0012 - mae: 0.0063 - val_loss: 8.1870e-04 - val_mae: 0.0034 - learning_rate: 0.0010
# Epoch 70/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0011 - mae: 0.0057 - val_loss: 5.9176e-04 - val_mae: 0.0037 - learning_rate: 0.0010
# Epoch 71/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0010 - mae: 0.0057 - val_loss: 5.9741e-04 - val_mae: 0.0034 - learning_rate: 0.0010
# Epoch 72/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0011 - mae: 0.0057 - val_loss: 8.7420e-04 - val_mae: 0.0039 - learning_rate: 0.0010
# Epoch 73/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.3379e-04 - mae: 0.0053 - val_loss: 6.6228e-04 - val_mae: 0.0031 - learning_rate: 0.0010
# Epoch 74/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0012 - mae: 0.0057 - val_loss: 4.0965e-04 - val_mae: 0.0033 - learning_rate: 0.0010
# Epoch 75/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0010 - mae: 0.0054 - val_loss: 8.4987e-04 - val_mae: 0.0031 - learning_rate: 0.0010
# Epoch 76/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.8872e-04 - mae: 0.0054 - val_loss: 7.1150e-04 - val_mae: 0.0049 - learning_rate: 0.0010
# Epoch 77/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0010 - mae: 0.0054 - val_loss: 7.1785e-04 - val_mae: 0.0033 - learning_rate: 0.0010
# Epoch 78/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.7731e-04 - mae: 0.0054 - val_loss: 5.4184e-04 - val_mae: 0.0025 - learning_rate: 0.0010
# Epoch 79/100
# 149/159 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0010 - mae: 0.0055
# Epoch 79: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.3243e-04 - mae: 0.0051 - val_loss: 5.4647e-04 - val_mae: 0.0024 - learning_rate: 0.0010
# Epoch 80/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.4548e-04 - mae: 0.0041 - val_loss: 4.9648e-04 - val_mae: 0.0021 - learning_rate: 5.0000e-04
# Epoch 81/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.9471e-04 - mae: 0.0038 - val_loss: 3.3898e-04 - val_mae: 0.0030 - learning_rate: 5.0000e-04
# Epoch 82/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.5771e-04 - mae: 0.0039 - val_loss: 5.3171e-04 - val_mae: 0.0027 - learning_rate: 5.0000e-04
# Epoch 83/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.4382e-04 - mae: 0.0036 - val_loss: 4.6495e-04 - val_mae: 0.0018 - learning_rate: 5.0000e-04
# Epoch 84/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.4881e-04 - mae: 0.0037 - val_loss: 2.9084e-04 - val_mae: 0.0021 - learning_rate: 5.0000e-04
# Epoch 85/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.6748e-04 - mae: 0.0040 - val_loss: 4.1876e-04 - val_mae: 0.0016 - learning_rate: 5.0000e-04
# Epoch 86/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.8530e-04 - mae: 0.0038 - val_loss: 4.2500e-04 - val_mae: 0.0019 - learning_rate: 5.0000e-04
# Epoch 87/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.6281e-04 - mae: 0.0039 - val_loss: 4.1983e-04 - val_mae: 0.0015 - learning_rate: 5.0000e-04
# Epoch 88/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3997e-04 - mae: 0.0033 - val_loss: 4.8849e-04 - val_mae: 0.0021 - learning_rate: 5.0000e-04
# Epoch 89/100
# 152/159 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.0635e-04 - mae: 0.0036
# Epoch 89: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.2828e-04 - mae: 0.0035 - val_loss: 5.9653e-04 - val_mae: 0.0028 - learning_rate: 5.0000e-04
# Epoch 90/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.8103e-04 - mae: 0.0031 - val_loss: 4.7027e-04 - val_mae: 0.0017 - learning_rate: 2.5000e-04
# Epoch 91/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9324e-04 - mae: 0.0028 - val_loss: 3.3531e-04 - val_mae: 0.0020 - learning_rate: 2.5000e-04
# Epoch 92/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6172e-04 - mae: 0.0028 - val_loss: 4.1823e-04 - val_mae: 0.0020 - learning_rate: 2.5000e-04
# Epoch 93/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5776e-04 - mae: 0.0029 - val_loss: 3.2903e-04 - val_mae: 0.0016 - learning_rate: 2.5000e-04
# Epoch 94/100
# 137/159 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.1593e-04 - mae: 0.0031
# Epoch 94: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9695e-04 - mae: 0.0029 - val_loss: 5.8804e-04 - val_mae: 0.0020 - learning_rate: 2.5000e-04

# %%
# ── 9. Evaluate ──────────────────────────────────────────────────────────────
y_pred_s = model.predict(X_test, verbose=0).flatten()
y_pred   = y_scaler.inverse_transform(y_pred_s.reshape(-1, 1)).flatten()

mse  = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mae  = mean_absolute_error(y_test, y_pred)
r2   = r2_score(y_test, y_pred)

print(f"MSE:  {mse:.4f}")
print(f"RMSE: {rmse:.4f}")
print(f"MAE:  {mae:.4f}")
print(f"R²:   {r2:.4f}")

# Actual vs predicted plot
fig, ax = plt.subplots(figsize=(6, 6))
ax.scatter(y_test, y_pred, alpha=0.2, s=5, color="steelblue")
lims = [min(y_test.min(), y_pred.min()), max(y_test.max(), y_pred.max())]
ax.plot(lims, lims, "r--", linewidth=1.5, label="Perfect prediction")
ax.set_xlabel("Actual WQI")
ax.set_ylabel("Predicted WQI")
ax.set_title(f"Actual vs Predicted — ANN (R²={r2:.4f})")
ax.legend()
plt.tight_layout()
plt.savefig(f"{OUTPUT_DIR}/actual_vs_predicted_ann.png", dpi=150)
plt.show()
# Out:
# MSE:  0.0152
# RMSE: 0.1235
# MAE:  0.0138
# R²:   0.9678

# %%
# ── 10. Training curves ───────────────────────────────────────────────────────
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
epochs_ran = range(1, len(history.history["loss"]) + 1)

ax1.plot(epochs_ran, history.history["loss"],     label="Train MSE")
ax1.plot(epochs_ran, history.history["val_loss"], label="Val MSE")
ax1.set_title("Loss (MSE)")
ax1.set_xlabel("Epoch")
ax1.set_ylabel("MSE")
ax1.legend()

ax2.plot(epochs_ran, history.history["mae"],     label="Train MAE")
ax2.plot(epochs_ran, history.history["val_mae"], label="Val MAE")
ax2.set_title("MAE")
ax2.set_xlabel("Epoch")
ax2.set_ylabel("MAE")
ax2.legend()

plt.tight_layout()
plt.savefig(f"{OUTPUT_DIR}/training_curves.png", dpi=150)
plt.show()
print(f"Saved to {OUTPUT_DIR}/training_curves.png")
# Out:
# Saved to output/training_curves.png

# %%
import joblib

# ── 11. Save model + scalers ──────────────────────────────────────────────────
model.save(f"{OUTPUT_DIR}/wqi_ann_model.keras")
joblib.dump(scaler,   f"{OUTPUT_DIR}/scaler.joblib")
joblib.dump(y_scaler, f"{OUTPUT_DIR}/y_scaler.joblib")
print(f"Saved: {OUTPUT_DIR}/wqi_ann_model.keras | scaler.joblib | y_scaler.joblib")
# Out:
# Saved: output/wqi_ann_model.keras | scaler.joblib | y_scaler.joblib

# %% [markdown]
# # Feature Ablation Study
#
# We use a Random Forest to rank feature importances, then iteratively remove the least important feature and re-train to observe the impact on macro F1-score.

# %%
from sklearn.ensemble import RandomForestRegressor

# ── Reload raw splits so we can index features freely ────────────────────────
df_ire = pd.read_csv(DATA_PATH)

# Apply same IQR outlier removal
df_abl = df_ire[FEATURES + [TARGET]].copy()
for col in FEATURES:
    Q1, Q3 = df_abl[col].quantile(0.25), df_abl[col].quantile(0.75)
    IQR = Q3 - Q1
    df_abl = df_abl[(df_abl[col] >= Q1 - 1.5 * IQR) & (df_abl[col] <= Q3 + 1.5 * IQR)]

X_raw = df_abl[FEATURES].values
y_raw = df_abl[TARGET].values.astype(float)

X_tr, X_te, y_tr, y_te = train_test_split(
    X_raw, y_raw, test_size=TEST_SIZE, random_state=RANDOM_SEED
)
X_tr, X_v, y_tr, y_v = train_test_split(
    X_tr, y_tr, test_size=VAL_SIZE, random_state=RANDOM_SEED
)

scaler_abl = StandardScaler()
X_tr_s = scaler_abl.fit_transform(X_tr)
X_te_s  = scaler_abl.transform(X_te)

# ── Train RF regressor on all 8 features → importance ranking ────────────────
rf_full = RandomForestRegressor(n_estimators=100, random_state=RANDOM_SEED, n_jobs=-1)
rf_full.fit(X_tr_s, y_tr)

importances = rf_full.feature_importances_
feat_names  = np.array(FEATURES)

sorted_idx = np.argsort(importances)   # least → most important
ranked_features = feat_names[sorted_idx]

print("Feature importance ranking (least → most important):")
for i, (name, imp) in enumerate(zip(ranked_features, importances[sorted_idx])):
    print(f"  {i+1}. {name:45s}  {imp:.4f}")
# Out:
# Feature importance ranking (least → most important):
#   1. Biochemical Oxygen Demand (mg/l)               0.0000
#   2. Nitrate (mg/l)                                 0.0000
#   3. Orthophosphate (mg/l)                          0.0000
#   4. Ammonia (mg/l)                                 0.0000
#   5. Nitrogen (mg/l)                                0.0000
#   6. Temperature (cel)                              0.0000
#   7. Dissolved Oxygen (mg/l)                        0.4357
#   8. pH (ph units)                                  0.5643

# %%
# ── Feature importance bar chart ─────────────────────────────────────────────
fig, ax = plt.subplots(figsize=(9, 5))
short_names = [n.split(" (")[0] for n in ranked_features]
bars = ax.barh(short_names, importances[sorted_idx], color="steelblue")
ax.set_xlabel("Mean Decrease in Impurity (Feature Importance)")
ax.set_title("Random Forest Feature Importances — Ireland Dataset")
ax.bar_label(bars, fmt="%.4f", padding=3, fontsize=9)
ax.set_xlim(0, importances.max() * 1.18)
plt.tight_layout()
plt.savefig(f"{OUTPUT_DIR}/feature_importances.png", dpi=150)
plt.show()
print(f"Saved to {OUTPUT_DIR}/feature_importances.png")
# Out:
# Saved to output/feature_importances.png

# %%
# ── Ablation: remove least important feature one by one ──────────────────────
# RF regressor; metric: R² on held-out test set

removal_order  = sorted_idx.tolist()   # least → most important
active_indices = list(range(len(FEATURES)))
results = []

for step in range(len(FEATURES)):
    col_idx  = active_indices[:]
    X_tr_sub = X_tr_s[:, col_idx]
    X_te_sub = X_te_s[:, col_idx]

    rf = RandomForestRegressor(n_estimators=100, random_state=RANDOM_SEED, n_jobs=-1)
    rf.fit(X_tr_sub, y_tr)
    y_pred_abl = rf.predict(X_te_sub)

    r2_abl  = r2_score(y_te, y_pred_abl)
    removed = FEATURES[removal_order[step - 1]] if step > 0 else "—"

    results.append({
        "n_features": len(active_indices),
        "removed":    removed,
        "r2":         r2_abl,
        "rmse":       np.sqrt(mean_squared_error(y_te, y_pred_abl)),
    })
    print(f"n={len(active_indices):2d}  R²={r2_abl:.4f}  RMSE={results[-1]['rmse']:.4f}  (removed: {removed})")

    if active_indices:
        drop = removal_order[step]
        active_indices = [i for i in active_indices if i != drop]

results_df = pd.DataFrame(results)
print("\n", results_df[["n_features", "removed", "r2", "rmse"]].to_string(index=False))
# Out:
# n= 8  R²=0.9998  RMSE=0.0097  (removed: —)
# n= 7  R²=0.9998  RMSE=0.0097  (removed: Biochemical Oxygen Demand (mg/l))
# n= 6  R²=0.9998  RMSE=0.0097  (removed: Nitrate (mg/l))
# n= 5  R²=0.9998  RMSE=0.0097  (removed: Orthophosphate (mg/l))
# n= 4  R²=0.9998  RMSE=0.0097  (removed: Ammonia (mg/l))
# n= 3  R²=0.9998  RMSE=0.0097  (removed: Nitrogen (mg/l))
# n= 2  R²=0.9998  RMSE=0.0097  (removed: Temperature (cel))
# n= 1  R²=0.5783  RMSE=0.4467  (removed: Dissolved Oxygen (mg/l))
#
#   n_features                          removed       r2     rmse
#           8                                — 0.999803 0.009659
#           7 Biochemical Oxygen Demand (mg/l) 0.999803 0.009659
#           6                   Nitrate (mg/l) 0.999803 0.009659
#           5            Orthophosphate (mg/l) 0.999803 0.009659
#           4                   Ammonia (mg/l) 0.999803 0.009659
#           3                  Nitrogen (mg/l) 0.999803 0.009659
#           2                Temperature (cel) 0.999803 0.009659
#           1          Dissolved Oxygen (mg/l) 0.578314 0.446722

# %%
# ── Ablation curve ────────────────────────────────────────────────────────────
fig, ax = plt.subplots(figsize=(9, 5))
ax.plot(results_df["n_features"], results_df["r2"], marker="o", linewidth=2, color="steelblue")
ax.set_xlabel("Number of Features")
ax.set_ylabel("R²")
ax.set_title("Feature Ablation — Ireland Dataset (RF Regressor)")
ax.set_xticks(results_df["n_features"])
ax.set_ylim(0, 1.05)
ax.grid(True, linestyle="--", alpha=0.5)

for _, row in results_df.iterrows():
    label = row["removed"].split(" (")[0] if row["removed"] != "—" else "all"
    ax.annotate(label, xy=(row["n_features"], row["r2"]),
                xytext=(0, 10), textcoords="offset points",
                ha="center", fontsize=7.5, rotation=30)

plt.tight_layout()
plt.savefig(f"{OUTPUT_DIR}/ablation_curve.png", dpi=150)
plt.show()
print(f"Saved to {OUTPUT_DIR}/ablation_curve.png")
# Out:
# Saved to output/ablation_curve.png

# %% [markdown]
# ## Permutation Importance vs. MDI
#
# Permutation importance measures how much macro F1 drops when a single feature's values are randomly shuffled on the **test set**. Unlike MDI, it is evaluated on held-out data and is not biased toward high-cardinality features.

# %%
from sklearn.inspection import permutation_importance

# Uses rf_full trained on all 8 features; scoring = R²
perm = permutation_importance(
    rf_full, X_te_s, y_te,
    scoring="r2",
    n_repeats=10,
    random_state=RANDOM_SEED,
    n_jobs=-1,
)

perm_means = perm.importances_mean
perm_stds  = perm.importances_std

print("Permutation importance (mean drop in R²):")
perm_order = np.argsort(perm_means)
for i in perm_order:
    print(f"  {FEATURES[i]:45s}  {perm_means[i]:.4f} +/- {perm_stds[i]:.4f}")
# Out:
# Permutation importance (mean drop in R²):
#   Ammonia (mg/l)                                 -0.0000 +/- 0.0000
#   Nitrogen (mg/l)                                -0.0000 +/- 0.0000
#   Orthophosphate (mg/l)                          -0.0000 +/- 0.0000
#   Biochemical Oxygen Demand (mg/l)               0.0000 +/- 0.0000
#   Nitrate (mg/l)                                 0.0000 +/- 0.0000
#   Temperature (cel)                              0.0000 +/- 0.0000
#   Dissolved Oxygen (mg/l)                        0.8361 +/- 0.0162
#   pH (ph units)                                  1.1621 +/- 0.0125

# %%
# ── Side-by-side MDI vs Permutation importance ───────────────────────────────
short = [n.split(" (")[0] for n in feat_names]

mdi_norm  = importances / importances.max()
perm_norm = perm_means  / perm_means.max() if perm_means.max() > 0 else perm_means

x     = np.arange(len(FEATURES))
width = 0.38

fig, ax = plt.subplots(figsize=(11, 5))
ax.bar(x - width/2, mdi_norm,  width, label="MDI (normalised)",        color="steelblue",  alpha=0.85)
ax.bar(x + width/2, perm_norm, width, label="Permutation (normalised)", color="darkorange", alpha=0.85,
       yerr=perm_stds / perm_means.max(), capsize=4)

ax.set_xticks(x)
ax.set_xticklabels(short, rotation=30, ha="right")
ax.set_ylabel("Normalised Importance")
ax.set_title("Feature Importance: MDI vs. Permutation (R²) — Ireland Dataset")
ax.legend()
ax.grid(axis="y", linestyle="--", alpha=0.4)

plt.tight_layout()
plt.savefig(f"{OUTPUT_DIR}/importance_comparison.png", dpi=150)
plt.show()
print(f"Saved to {OUTPUT_DIR}/importance_comparison.png")
# Out:
# Saved to output/importance_comparison.png
